# %%
# !pip install opencv-python
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\mikae\anaconda3\lib\site-packages\mask_rcnn-2.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import cv2
